# %%
import os

# %%
import warnings 
warnings.simplefilter("ignore")

# %%
import numpy as np

# %%
import pandas as  pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread,imshow 
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
karthi=os.listdir("C:/Users/SN137/S.UTHAYA KUMAR/uthaya1")
surya=os.listdir("C:/Users/SN137/S.UTHAYA KUMAR/uthaya1")

# %%
karthi
# Out:
# ['suriya1.jpg',
#  'suriya10.jpeg',
#  'suriya12.jpeg',
#  'suriya13.jpg',
#  'suriya14.jpg',
#  'suriya15.jpg',
#  'suriya16.jpg',
#  'suriya18.jpg',
#  'suriya4.jpg',
#  'suriya5.jpg',
#  'suriya6.jpg',
#  'suriya7.jpg',
#  'suriya8.jpeg',
#  'suriya8.jpg',
#  'suriya9.jpeg']

# %%
limit=10
surya_images=[None]*limit
c=0
for i in surya:
    if c<limit:
        surya_images[c]=imread("C:/Users/SN137/S.UTHAYA KUMAR/uthaya1/"+i)
        c+=1
    else:
        break

# %%
imshow(surya_images[5])

# %%
len(surya_images)
# Out:
# 10

# %%
surya_gray=[None]*limit
c=0
for i in surya:
    if c < limit:
        surya_gray[c]=rgb2gray(surya_images[c])
        c+=1
    else:
        break

# %%
imshow(surya_gray[5])

# %%
for i in range(10):
    s=surya_gray[i]
    surya_gray[i]=resize(s,(512,512))

# %%
s_len=len(surya_gray)

# %% [markdown]
# # B.Flatting the image

# %%
Img_Size_surya=surya_gray[1].shape

# %%
Img_Size_surya
# Out:
# (512, 512)

# %%
flatten_Img_Size_surya=Img_Size_surya[0]*Img_Size_surya[1]

# %%
flatten_Img_Size_surya
# Out:
# 262144
