# %% [markdown]
# # Machine Learning - Supervised Learning

# %% [markdown]
# 1.Regression
# 2.Classification

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # IMPORTING DATA SET

# %%
ds=pd.read_csv("C:/Users/SN137/Downloads/Admission_Predict.csv")

# %%
ds
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#     Research  Chance of Admit
# ...

# %%
ds2=ds.drop(['Serial No.','GRE Score','TOEFL Score','University Rating','SOP' , 'LOR ' ,'Research'],axis=1)

# %%
ds2
# Out:
#      CGPA  Chance of Admit
# 0    9.65              0.92
# 1    8.87              0.76
# 2    8.00              0.72
# 3    8.67              0.80
# 4    8.21              0.65
# ..    ...               ...
# 395  9.04              0.82
# 396  9.11              0.84
# 397  9.45              0.91
# 398  8.78              0.67
# 399  9.66              0.95
#
# [400 rows x 2 columns]

# %%
x=ds2.iloc[:,0]

# %%
x
# Out:
# 0      9.65
# 1      8.87
# 2      8.00
# 3      8.67
# 4      8.21
#        ...
# 395    9.04
# 396    9.11
# 397    9.45
# 398    8.78
# 399    9.66
# Name: CGPA, Length: 400, dtype: float64

# %%
x=ds2.iloc[:,0].values.reshape(-1,1)
y=ds2.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[9.65],
#        [8.87],
#        [8.  ],
#        [8.67],
#        [8.21],
#        [9.34],
#        [8.2 ],
#        [7.9 ],
#        [8.  ],
#        [8.6 ],
#        [8.4 ],
#        [9.  ],
#        [9.1 ],
#        [8.  ],
#        [8.2 ],
#        [8.3 ],
#        [8.7 ],
#        [8.  ],
#        [8.8 ],
#        [8.5 ],
#        [7.9 ],
#        [8.4 ],
#        [9.5 ],
#        [9.7 ],
#        [9.8 ],
#        [9.6 ],
#        [8.8 ],
#        [7.5 ],
#        [7.2 ],
#        [7.3 ],
#        [8.1 ],
#        [8.3 ],
#        [9.4 ],
#        [9.6 ],
#        [9.8 ],
#        [9.2 ],
#        [8.4 ],
#        [7.8 ],
#        [7.5 ],
#        [7.7 ],
#        [8.  ],
#        [8.2 ],
#        [8.5 ],
#        [9.1 ],
#        [9.4 ],
#        [9.1 ],
#        [9.3 ],
#        [9.7 ],
#        [8.85],
#        [8.4 ],
#        [8.3 ],
#        [7.9 ],
#        [8.  ],
#        [8.1 ],
#        [8.  ],
#        [7.7 ],
#        [7.4 ],
#        [7.6 ],
# ...

# %% [markdown]
# # Split The Data Set

# %%
pip install scikit_learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
y_test
# Out:
# array([[0.71],
#        [0.7 ],
#        [0.79],
#        [0.73],
#        [0.72],
#        [0.48],
#        [0.77],
#        [0.71],
#        [0.9 ],
#        [0.94],
#        [0.58],
#        [0.89],
#        [0.72],
#        [0.57],
#        [0.78],
#        [0.42],
#        [0.64],
#        [0.84],
#        [0.63],
#        [0.72],
#        [0.9 ],
#        [0.83],
#        [0.57],
#        [0.47],
#        [0.85],
#        [0.67],
#        [0.44],
#        [0.54],
#        [0.92],
#        [0.62],
#        [0.68],
#        [0.73],
#        [0.73],
#        [0.61],
#        [0.55],
#        [0.74],
#        [0.64],
#        [0.89],
#        [0.73],
#        [0.95],
#        [0.71],
#        [0.72],
#        [0.75],
#        [0.76],
#        [0.86],
#        [0.7 ],
#        [0.39],
#        [0.79],
#        [0.61],
#        [0.64],
#        [0.71],
#        [0.8 ],
#        [0.61],
#        [0.89],
#        [0.68],
#        [0.79],
#        [0.78],
#        [0.52],
# ...
