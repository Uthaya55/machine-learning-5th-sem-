# %%
import pandas as pd

# %%
File=pd.read_csv("C:/Users/SN137/Downloads/ndtv_data_final.csv")

# %%
File
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 1354        1354                   Intex Aqua A2     Intex
# 1355        1355     Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                   Intex Aqua Y4     Intex
# 1357        1357                 iBall Andi4 B20     iBall
# 1358        1358             iBall Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %%
File.drop("Unnamed: 0",axis=1)
# Out:
#                                 Name     Brand                   Model  \
# 0     OnePlus 7T Pro McLaren Edition   OnePlus  7T Pro McLaren Edition
# 1                      Realme X2 Pro    Realme                  X2 Pro
# 2                  iPhone 11 Pro Max     Apple       iPhone 11 Pro Max
# 3                          iPhone 11     Apple               iPhone 11
# 4                       LG G8X ThinQ        LG               G8X ThinQ
# ...                              ...       ...                     ...
# 1354                   Intex Aqua A2     Intex                 Aqua A2
# 1355     Videocon Infinium Z51 Nova+  Videocon      Infinium Z51 Nova+
# 1356                   Intex Aqua Y4     Intex                 Aqua Y4
# 1357                 iBall Andi4 B20     iBall               Andi4 B20
# 1358             iBall Andi Avonte 5     iBall           Andi Avonte 5
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# ...

# %%
File["Name"]=File["Name"].str.strip('Edition').astype(str)

# %%
File
# Out:
#       Unnamed: 0                         Name     Brand  \
# 0              0      OnePlus 7T Pro McLaren    OnePlus
# 1              1                 Realme X2 Pr    Realme
# 2              2             Phone 11 Pro Max     Apple
# 3              3                     Phone 11     Apple
# 4              4                 LG G8X ThinQ        LG
# ...          ...                          ...       ...
# 1354        1354                Intex Aqua A2     Intex
# 1355        1355  Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                Intex Aqua Y4     Intex
# 1357        1357               Ball Andi4 B20     iBall
# 1358        1358           Ball Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %%
File["Name"]=File["Name"].str.strip('Edition').astype(str)

# %%
File
# Out:
#       Unnamed: 0                         Name     Brand  \
# 0              0      OnePlus 7T Pro McLaren    OnePlus
# 1              1                 Realme X2 Pr    Realme
# 2              2             Phone 11 Pro Max     Apple
# 3              3                     Phone 11     Apple
# 4              4                 LG G8X ThinQ        LG
# ...          ...                          ...       ...
# 1354        1354                Intex Aqua A2     Intex
# 1355        1355  Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                Intex Aqua Y4     Intex
# 1357        1357               Ball Andi4 B20     iBall
# 1358        1358           Ball Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %% [markdown]
# # CATAGORICAL DATA

# %%
Data=pd.DataFrame({"Salary":[10000,20000,30000,40000,50000],"Range":["LOW","LOW","MID","HIGH","HIGH"]})

# %%
Data
# Out:
#    Salary Range
# 0   10000   LOW
# 1   20000   LOW
# 2   30000   MID
# 3   40000  HIGH
# 4   50000  HIGH

# %%
code=Data.Range.map({"LOW":3,"HIGH":1,"MID":2})

# %%
code
# Out:
# 0    3
# 1    3
# 2    2
# 3    1
# 4    1
# Name: Range, dtype: int64

# %%
publish=pd.DataFrame(Data["Salary"],columns=["Salary"])

# %%
publish["code"]=code

# %%
publish
# Out:
#    Salary  code
# 0   10000     3
# 1   20000     3
# 2   30000     2
# 3   40000     1
# 4   50000     1

# %% [markdown]
# # FEATURE SCALING

# %%
import numpy as np

# %%
Test_Data=pd.DataFrame({'x':np.random.randint(-1,100,1000),
                        'y':np.random.randint(-50,50,1000),
                        'z':np.random.randint(-200,200,1000)})

# %%
Test_Data
# Out:
#       x   y    z
# 0    66  38 -142
# 1    53 -42  -69
# 2    52  12   23
# 3    82  30  -11
# 4    29   9  -52
# ..   ..  ..  ...
# 995  98 -14 -163
# 996  61 -26  116
# 997  40  19   62
# 998  79  46  187
# 999  45  -3 -149
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
pl=plt.axes(projection='3d')

# %%
pl=plt.axes(projection='3d')
pl.scatter3D(Test_Data.x,Test_Data.y,Test_Data.z)
plt.figure()

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import Normalizer

# %%
nm=Normalizer()

# %%
Normal_Data=nm.fit_transform(Test_Data)

# %%
Normal_Data
# Out:
# array([[ 0.40959829,  0.23582932, -0.88125693],
#        [ 0.54858253, -0.43472578, -0.71419235],
#        [ 0.89482439,  0.20649794,  0.39578771],
#        ...,
#        [ 0.52499949,  0.24937476,  0.81374921],
#        [ 0.37953584,  0.22099555,  0.89839496],
#        [ 0.289062  , -0.0192708 , -0.9571164 ]])

# %%
Normal_df=pd.DataFrame(Normal_Data,columns=['a','b','c'])

# %%
pl=plt.axes(projection='3d')
pl.scatter3D(Normal_df.a,Normal_df.b,Normal_df.c)
plt.figure()

# %% [markdown]
# # MISSING VALUES

# %%
data={"A":[1,2,3,4,5],
      "B":[10,40,np.nan,80,60],
      "c":[np.nan,np.nan,100,50,60]}

# %%
DF=pd.DataFrame(data)

# %%
DF
# Out:
#    A     B      c
# 0  1  10.0    NaN
# 1  2  40.0    NaN
# 2  3   NaN  100.0
# 3  4  80.0   50.0
# 4  5  60.0   60.0

# %%
from sklearn.impute import SimpleImputer

# %%
SM=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
SM.fit(DF)
# Out:
# SimpleImputer()

# %%
SM=SimpleImputer(missing_values=np.nan,strategy='median')

# %%
SM.fit(DF)
# Out:
# SimpleImputer(strategy='median')

# %%
SM.transform(DF)
# Out:
# array([[  1.,  10.,  60.],
#        [  2.,  40.,  60.],
#        [  3.,  50., 100.],
#        [  4.,  80.,  50.],
#        [  5.,  60.,  60.]])

# %%
SM=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
SM.fit(DF)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
SM.transform
# Out:
# <bound method SimpleImputer.transform of SimpleImputer(strategy='most_frequent')>

# %%
SM=SimpleImputer(missing_values=np.nan,strategy='constant')

# %%
SM.fit(DF)
# Out:
# SimpleImputer(strategy='constant')

# %%
SM.transform(DF)
# Out:
# array([[  1.,  10.,   0.],
#        [  2.,  40.,   0.],
#        [  3.,   0., 100.],
#        [  4.,  80.,  50.],
#        [  5.,  60.,  60.]])
